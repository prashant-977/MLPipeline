# %%
# Install Kaggle
# %pip install kaggle

# Setup Kaggle credentials
import os
os.environ['KAGGLE_USERNAME'] = "pmahato"
os.environ['KAGGLE_KEY'] = "<KAGGLE_KEY>"

# Download data
# !kaggle competitions download -c allstate-claims-severity

# Unzip
# !unzip allstate-claims-severity.zip

# Move to DBFS
dbutils.fs.mv("file:/databricks/driver/train.csv", "/mnt/datalake/raw/allstate/train.csv")
dbutils.fs.mv("file:/databricks/driver/test.csv", "/mnt/datalake/raw/allstate/test.csv")

# %%
# Simple read and display
df = spark.read.csv("/mnt/datalake/raw/allstate/train.csv", header=True, inferSchema=True)
display(df.limit(10))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
